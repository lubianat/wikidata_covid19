# %%
import pandas as pd

complexes_data = pd.read_csv("../data/sars-cov-2.tsv", sep = "\t")
complexes_data.head(2)
# Out:
#   #Complex ac                                Recommended name  \
# 0    CPX-5683  SARS-CoV-2 Spike - human ACE2 receptor complex
# 1    CPX-5684   SARS-CoV-2 Spike - human ACE2-SLC6A19 complex
#
#   Aliases for complex  Taxonomy identifier  \
# 0                   -              2697049
# 1                   -              2697049
#
#   Identifiers (and stoichiometry) of molecules in complex  \
# 0                              Q9BYF1(1)|CPX-5682(1)
# 1  Q9BYF1(1)|Q9BYF1(1)|Q695T7(1)|CPX-5682(1)|Q695...
#
#                                           Confidence Experimental evidence  \
# 0  ECO:0000353(physical interaction evidence used...   intact:EBI-25475360
# 1  ECO:0000353(physical interaction evidence used...   intact:EBI-25475756
#
#   Go Annotations                                   Cross references  \
# 0              -  emdb:EMD-21457(subset)|wwpdb:6lzg(identity)|pu...
# 1              -  emdb:EMD-21457(subset)|pubmed:32203189(see-als...
#
#                                          Description Complex properties  \
# 0  Binding of SARS-CoV-2 coronavirus Spike protei...                  -
# 1  Internalised SARS-CoV-2 coronavirus Spike - hu...                  -
#
#   Complex assembly Ligand                                            Disease  \
# 0   Heteroheptamer      -  Severe acute respiratory syndrome (SARS) [EFO:...
# 1    Heterodecamer      -  Severe acute respiratory syndrome (SARS) [EFO:...
#
#   Agonist Antagonist Comment                    Source
# 0       -          -       -  psi-mi:"MI:0469"(IntAct)
# 1       -          -       -  psi-mi:"MI:0469"(IntAct)

# %%
# Okay, now let's create a ID to Wikidata reference object.

# From https://covid-19.uniprot.org/uniprotkb/P0DTD1 we imported infos to OpenRefine

# We created the items for the proteins derived of P0DTD1-PRO_0000449628.

open_refine_reference = pd.read_csv("../intermediate/openrefine_replicase_frags.tsv", sep="\t")
open_refine_reference["code_as_in_complexes_data"] = open_refine_reference["PDB ID"] + "-" + open_refine_reference["ID"] 
open_refine_reference.head(2)
# Out:
#    Column   Type Positions                                   Description  \
# 0     NaN  chain    1-7096                     Replicase polyprotein 1ab
# 1     NaN  chain     1-180  Host translation inhibitor nsp1 [SARS-CoV-2]
#
#   qid_updated              ID  Column2  PDB ID code_as_in_complexes_data
# 0         NaN  PRO_0000449618      NaN  P0DTD1     P0DTD1-PRO_0000449618
# 1   Q90038952  PRO_0000449619      NaN  P0DTD1     P0DTD1-PRO_0000449619

# %%
# We also need to get  the ids from the complexes in Wikidata, of course. Once again, OpenRefine is the way to go.
open_refine_complexes = pd.read_csv("../intermediate/openrefine_complexes.tsv", sep="\t")
open_refine_complexes.head(2)
# Out:
#   #Complex ac                                Recommended name complex_qid  \
# 0    CPX-5683  SARS-CoV-2 Spike - human ACE2 receptor complex   Q90012260
# 1    CPX-5684   SARS-CoV-2 Spike - human ACE2-SLC6A19 complex   Q90012261
#
#   Aliases for complex  Taxonomy identifier  \
# 0                   -              2697049
# 1                   -              2697049
#
#   Identifiers (and stoichiometry) of molecules in complex  \
# 0                              Q9BYF1(1)|CPX-5682(1)
# 1  Q9BYF1(1)|Q9BYF1(1)|Q695T7(1)|CPX-5682(1)|Q695...
#
#                                           Confidence Experimental evidence  \
# 0  ECO:0000353(physical interaction evidence used...   intact:EBI-25475360
# 1  ECO:0000353(physical interaction evidence used...   intact:EBI-25475756
#
#   Go Annotations                                   Cross references  \
# 0              -  emdb:EMD-21457(subset)|wwpdb:6lzg(identity)|pu...
# 1              -  emdb:EMD-21457(subset)|pubmed:32203189(see-als...
#
#                                          Description Complex properties  \
# 0  Binding of SARS-CoV-2 coronavirus Spike protei...                  -
# 1  Internalised SARS-CoV-2 coronavirus Spike - hu...                  -
#
#   Complex assembly Ligand                                            Disease  \
# 0   Heteroheptamer      -  Severe acute respiratory syndrome (SARS) [EFO:...
# 1    Heterodecamer      -  Severe acute respiratory syndrome (SARS) [EFO:...
#
#   Agonist Antagonist Comment                    Source
# 0       -          -       -  psi-mi:"MI:0469"(IntAct)
# 1       -          -       -  psi-mi:"MI:0469"(IntAct)

# %%
# Cool, but some repetion of subunits are not identified in the (stoichiometry) part. 
# I guess I could write code to clean that up, but for now I will do it manually. 

open_refine_complexes_manually_edited = pd.read_csv("../intermediate/openrefine_complexes_manual_edit.tsv", sep="\t")

# %%
# Convert to quickstatements only the complexes that are derived of P0DTD1: 


! touch ../p0dtd1_quickstatements.txt
for index, row in open_refine_complexes_manually_edited.iterrows():
    
    complex_composition = row["Identifiers (and stoichiometry) of molecules in complex"]
    complex_qid = row["complex_qid"]
    cpx_id = row["#Complex ac"]
    reference = '|S248|Q47196990|S7718|"' + cpx_id + '"|S813|+2020-04-10T00:00:00Z/11|S854|"ftp://ftp.ebi.ac.uk/pub/databases/intact/complex/current/complextab"|S7793|"sars-cov-2.tsv"'
            
    if "P0DTD1" in complex_composition:
        ids_in_this_complex = complex_composition.split("|")
        
        for id_and_amount in ids_in_this_complex:
            
            id_and_amount = id_and_amount.replace(")", "")
            id_and_amount_tuple = id_and_amount.split("(")
            print(id_and_amount_tuple)
            subunit_qid = open_refine_reference["qid_updated"][open_refine_reference["code_as_in_complexes_data"] ==id_and_amount_tuple[0]]
            print(subunit_qid)
            amount = id_and_amount_tuple[1]
            # complex_qid + " has part " + qid + " in the amount " + amount + reference
            quickstatements_code = complex_qid + "|P527|" + subunit_qid + "|P1114|" + amount + reference
            with open("../p0dtd1_quickstatements.txt", "a") as myfile:
                myfile.write(quickstatements_code.values[0] + "\n")
# Out:
# ['P0DTD1-PRO_0000449623', '2']
# 5    Q87917582
# Name: qid_updated, dtype: object
# ['P0DTD1-PRO_0000449627', '2']
# 9    Q90038981
# Name: qid_updated, dtype: object
# ['P0DTD1-PRO_0000449628', '1']
# 10    Q90042394
# Name: qid_updated, dtype: object
# ['P0DTD1-PRO_0000449633', '1']
# 15    Q87917580
# Name: qid_updated, dtype: object
# ['P0DTD1-PRO_0000449632', '6']
# 14    Q90042811
# Name: qid_updated, dtype: object
# ['P0DTD1-PRO_0000449626', '8']
# 8    Q88659350
# Name: qid_updated, dtype: object
# ['P0DTD1-PRO_0000449625', '8']
# 7    Q90038963
# Name: qid_updated, dtype: object
# ['P0DTD1-PRO_0000449621', '0']
# 3    Q89560425
# Name: qid_updated, dtype: object
# ['P0DTD1-PRO_0000449622', '0']
# 4    Q90038956
# Name: qid_updated, dtype: object
# ['P0DTD1-PRO_0000449624', '0']
# 6    Q88656943
# Name: qid_updated, dtype: object
# ['P0DTD1-PRO_0000449631', '0']
# 13    Q90042407
# Name: qid_updated, dtype: object
# ['P0DTD1-PRO_0000449628', '0']
# 10    Q90042394
# Name: qid_updated, dtype: object

# %%
# Out:
# 10    NaN
# Name: qid_updated, dtype: object
