# %%
from wikidata2df import wikidata2df

# %%
query_for_vaccinations = """
SELECT 
  DISTINCT 
  # Remove ?item and ?title to generate table
  # in Quickstatements V1 syntax
  # ?item ?itemLabel

WHERE {

  # ?item wdt:P31 wd:Q104549533.
  MINUS{?item wdt:P1269 ?of.}
  
  # ?item rdfs:label ?label.
  
  FILTER(lang(?label)="en")
  FILTER(CONTAINS(lcase(?label), "covid"))
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }

}
"""

vaccinations = wikidata2df(query_for_vaccinations)

# %%
query_for_countries = """
SELECT DISTINCT ?item ?itemLabel ?country ?countryLabel WHERE { 
  # ?item p:P31 [
              ps:P31 wd:Q3241045;
              pq:P642 wd:Q84263196;
              pq:P3005 ?country
              ].
  values ?type_of_country {wd:Q3624078 wd:Q6256}.
  # ?country wdt:P31 ?type_of_country.

  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". } 
}
ORDER BY ?country ?dates
"""

countries = wikidata2df(query_for_countries)

# %%
vaccinations
# Out:
#                                             itemLabel         of       item  \
# 0   Timeline of the COVID-19 pandemic in February ...  Q81068910  Q85173796
# 1     Timeline of the COVID-19 pandemic in March 2020  Q81068910  Q87774378
# 2                   Timeline of the COVID-19 pandemic  Q84263196  Q83493517
# 3                   Timeline of the COVID-19 pandemic  Q81068910  Q83493517
# 4   timeline of the 2020 coronavirus pandemic in t...  Q83873577  Q87952372
# ..                                                ...        ...        ...
# 82  Timeline of the 2020 coronavirus pandemic in T...  Q87473205  Q88616161
# 83         Timeline of the COVID-19 pandemic in Japan  Q83872291  Q88650827
# 84    Timeline of the COVID-19 pandemic in April 2020  Q81068910  Q89016387
# 85  timeline of the 2020 coronavirus pandemic in S...  Q84166704  Q89663058
# 86         Timeline of the COVID-19 pandemic in India  Q84055514  Q88894143
#
#                                    ofLabel
# ...

# %%
for index, row in vaccinations.iterrows():
    
    vaccination_qid = row["item"]
    vaccination_label = row["itemLabel"]
    
    for index2, row2 in countries.iterrows():
        
        if row2["countryLabel"].lower() in vaccination_label.lower():
            pandemic_qid = row2["item"]
            print(vaccination_qid + "|P1269|" + pandemic_qid + "|S887|Q84423633" )
# Out:
# Q105209445|P1269|Q87250752|S887|Q84423633
# Q105209445|P1269|Q87454162|S887|Q84423633
# Q105576466|P1269|Q85876114|S887|Q84423633
# Q105623663|P1269|Q83873548|S887|Q84423633
# Q105637657|P1269|Q87450756|S887|Q84423633
# Q105653634|P1269|Q83873580|S887|Q84423633
# Q105690890|P1269|Q83873556|S887|Q84423633
# Q105653489|P1269|Q87483673|S887|Q84423633
# Q105810004|P1269|Q87592982|S887|Q84423633
# Q106091319|P1269|Q88164033|S887|Q84423633
# Q106103251|P1269|Q88082639|S887|Q84423633
# Q106103285|P1269|Q89164046|S887|Q84423633
# Q106103318|P1269|Q87665364|S887|Q84423633
# Q106103368|P1269|Q88082534|S887|Q84423633
# Q106103418|P1269|Q87058723|S887|Q84423633
# Q106103545|P1269|Q87202921|S887|Q84423633
# Q106104069|P1269|Q87243915|S887|Q84423633
